# %% [markdown]
# # A Deep Dive into the 2017 Kaggle ML and Data Science Survey Results
#
#
# DATA 512 - UW Interdisciplinary Data Science Masters Program
#
# Course Project Plan
#
# Mobing Zhuang
#
#
# ## 1. Project Introduction
#
# ### 1.1 About the survey
#
# In 2017, Kaggle conducted a [survey](https://www.kaggle.com/kaggle/kaggle-survey-2017) through Kaggle channels with the intention to establish a comprehensive view of the current state of data science and machine learning field.
#
# 16,716 usable survey responses were received from 171 countries and territories. The respondents were found through kaggle email list, discussion forums and social media channels. Questions in the survey consists of required and non-required ones. Survey responses were flagged as "spam" if their employment status, which is the first required question, was not answered. The survey is designed to only asking relevant questions to each respondent. In summary, this was a very well designed survey.
#
# ### 1.2 About the data
#
# The data sets includes 5 files:
#
# - schema.csv: This CSV file includes the survey questions that correspond to each column name in both the multipleChoiceResponses.csv and freeformResponses.csv.
# - multipleChoiceResponses.csv: Respondents' answers to multiple choice and ranking questions. A single row is the answer from the same respondent.
# - freeformResponses.csv: Respondents' freeform answers to Kaggle's survey questions. A single row is not the answer from the same respondent.
# - conversionRates.csv: Currency conversion rates to USD 7.
# - RespondentTypeREADME.txt: This describes respondent type in the "Asked" column of the schema.csv file.
#
# License:
#
# According to Kaggle, the data is released under Open Database license, specifically, [ODC Open Database License (ODbL)](https://opendatacommons.org/licenses/odbl/1.0/). Users are free to share, to produce works, to modify, transform and build upon the data, as long as they attribute, share-alike, and keep open. [Click to read detailed explanations of how the data can be used.](https://opendatacommons.org/licenses/odbl/summary/)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Project Background

# %%
# Scatter Plot
library(plotly)

set.seed(123)

x <- rnorm(1000)
y <- rchisq(1000, df = 1, ncp = 0)
group <- sample(LETTERS[1:5], size = 1000, replace = T)
size <- sample(1:5, size = 1000, replace = T)

ds <- data.frame(x, y, group, size)

p <- plot_ly(ds, x = x, y = y, mode = "markers", split = group, size = size) %>%
  layout(title = "Scatter Plot")
embed_notebook(p)
# Out:
# No trace type specified:
#   Based on info supplied, a 'scatter' trace seems appropriate.
#   Read more about this trace type -> https://plot.ly/r/reference/#scatter
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Research Questions and Methods

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Findings and Discussion

# %%
library(dplyr)
library(plotly)

# %%
plotly.__version__
plotly.offline.init_notebook_mode(connected=True)
plotly.plotly.sign_in('45220Zmb', '9EywutMKCyDsD5WpWSp9')
# Out:
# Error in eval(expr, envir, enclos): object 'plotly.__version__' not found
# Traceback:

# %%
## Read raw data
convRate <- read.csv("./RawData/conversionRates.csv")
freeRes <- read.csv("./RawData/freeformResponses.csv")
multiRes <- read.csv("./RawData/multipleChoiceResponses.csv")
schema <- read.csv("./RawData/schema.csv")

# %%
summary(multiRes)
# Out:
#                                             GenderSelect
#                                                   :   95
#  A different identity                             :  159
#  Female                                           : 2778
#  Male                                             :13610
#  Non-binary, genderqueer, or gender non-conforming:   74
#
#
#                         Country          Age
#  United States              :4197   Min.   :  0.00
#  India                      :2704   1st Qu.: 25.00
#  Other                      :1023   Median : 30.00
#  Russia                     : 578   Mean   : 32.37
#  United Kingdom             : 535   3rd Qu.: 37.00
#  People 's Republic of China: 471   Max.   :100.00
#  (Other)                    :7208   NA's   :331
#                                              EmploymentStatus StudentStatus
#  Employed full-time                                  :10897      :15436
#  Employed part-time                                  :  917   No :  299
#  I prefer not to say                                 :  420   Yes:  981
#  Independent contractor, freelancer, or self-employed: 1330
#  Not employed, and not looking for work              :  924
#  Not employed, but looking for work                  : 2110
#  Retired                                             :  118
#                                                             LearningDataScience
#                                                                       :15432
#  No, I am not focused on learning data science skills                 :   55
#  Yes, but data science is a small part of what I'm focused on learning:  429
#  Yes, I'm focused on learning mostly data science skills              :  800
#
#
#
#  CodeWriter  CareerSwitcher                          CurrentJobTitleSelect
#     : 3530      :13704                                          :4886
#  No : 3033   No :  886      Data Scientist                      :2433
#  Yes:10153   Yes: 2126      Software Developer/Software Engineer:1759
#                             Other                               :1233
#                             Data Analyst                        :1213
#                             Scientist/Researcher                : 978
#                             (Other)                             :4214
#       TitleFit
#           :5212
#  Fine     :7501
#  Perfectly:2305
#  Poorly   :1698
#
#
#
#                                                     CurrentEmployerType
#                                                               :5115
#  Employed by professional services/consulting firm            :2383
#  Employed by a company that performs advanced analytics       :2240
#  Employed by a company that doesn't perform advanced analytics:1974
#  Employed by college or university                            :1662
#  Employed by company that makes advanced analytic software    : 950
#  (Other)                                                      :2392
#       MLToolNextYearSelect          MLMethodNextYearSelect
#                 :5718                          :5883
#  TensorFlow     :2621      Deep learning       :4362
#  Python         :1713      Neural Nets         :1386
#  R              : 910      Time Series Analysis: 680
#  Spark / MLlib  : 755      Bayesian Methods    : 511
#  Hadoop/Hive/Pig: 417      Text Mining         : 493
#  (Other)        :4582      (Other)             :3401
#  LanguageRecommendationSelect
#  Python  :6941
#          :5718
#  R       :2643
#  SQL     : 385
#  C/C++/C#: 307
#  Matlab  : 238
#  (Other) : 484
#                                                                  PublicDatasetsSelect
#                                                                            :5920
#  Dataset aggregator/platform (i.e. Socrata/Kaggle Datasets/data.world/etc.):2950
#  Google Search                                                             :1052
#  I collect my own data (e.g. web-scraping)                                 : 564
#  University/Non-profit research group websites                             : 558
#  GitHub                                                                    : 540
#  (Other)                                                                   :5132
#         LearningPlatformSelect LearningPlatformUsefulnessArxiv
#                    : 5445                     :14325
#  Kaggle            :  210      Not Useful     :   37
#  Online courses    :  209      Somewhat useful: 1038
#  Personal Projects :  155      Very useful    : 1316
#  College/University:  127
#  YouTube Videos    :  127
#  (Other)           :10443
#  LearningPlatformUsefulnessBlogs LearningPlatformUsefulnessCollege
#                 :11951                          :13357
#  Not Useful     :   45           Not Useful     :  101
#  Somewhat useful: 2406           Somewhat useful: 1405
#  Very useful    : 2314           Very useful    : 1853
#
#
#
#  LearningPlatformUsefulnessCompany LearningPlatformUsefulnessConferences
#                 :15735                            :14534
#  Not Useful     :   41             Not Useful     :  119
#  Somewhat useful:  502             Somewhat useful: 1305
#  Very useful    :  438             Very useful    :  758
#
#
#
#  LearningPlatformUsefulnessFriends LearningPlatformUsefulnessKaggle
#                 :15135                            :10133
#  Not Useful     :   51             Not Useful     :   56
#  Somewhat useful:  774             Somewhat useful: 2451
#  Very useful    :  756             Very useful    : 4076
#
#
#
#  LearningPlatformUsefulnessNewsletters LearningPlatformUsefulnessCommunities
#                 :15627                                :15574
#  Not Useful     :   56                 Not Useful     :   16
#  Somewhat useful:  686                 Somewhat useful:  567
#  Very useful    :  347                 Very useful    :  559
#
#
#
#  LearningPlatformUsefulnessDocumentation LearningPlatformUsefulnessCourses
#                 :14395                                  :10724
#  Not Useful     :   42                   Not Useful     :   47
#  Somewhat useful: 1067                   Somewhat useful: 1750
#  Very useful    : 1212                   Very useful    : 4195
#
#
#
#  LearningPlatformUsefulnessProjects LearningPlatformUsefulnessPodcasts
#                 :11922                             :15502
#  Not Useful     :   39              Not Useful     :  124
#  Somewhat useful: 1185              Somewhat useful:  818
#  Very useful    : 3570              Very useful    :  272
#
#
#
#   LearningPlatformUsefulnessSO LearningPlatformUsefulnessTextbook
#                 :11076                        :12535
#  Not Useful     :   64         Not Useful     :   69
#  Somewhat useful: 2044         Somewhat useful: 1796
#  Very useful    : 3532         Very useful    : 2316
#
#
#
#  LearningPlatformUsefulnessTradeBook LearningPlatformUsefulnessTutoring
#                 :16383                              :15290
#  Not Useful     :    9               Not Useful     :   32
#  Somewhat useful:  162               Somewhat useful:  569
#  Very useful    :  162               Very useful    :  825
#
#
#
#  LearningPlatformUsefulnessYouTube
#                 :11487
#  Not Useful     :  104
#  Somewhat useful: 2605
#  Very useful    : 2520
#
#
#
#                                    BlogsPodcastsNewslettersSelect
#                                                   :8576
#  Other (Separate different answers with semicolon): 608
#  KDnuggets Blog                                   : 498
#  R Bloggers Blog Aggregator                       : 414
#  O'Reilly Data Newsletter                         : 234
#  Becoming a Data Scientist Podcast                : 223
#  (Other)                                          :6163
#  LearningDataScienceTime JobSkillImportanceBigData JobSkillImportanceDegree
#             :12367                   :12760                    :12807
#  < 1 year   : 2093       Necessary   : 1503        Necessary   : 1094
#  1-2 years  : 1566       Nice to have: 2271        Nice to have: 2338
#  10-15 years:   14       Unnecessary :  182        Unnecessary :  477
#  15+ years  :   30
#  3-5 years  :  540
#  5-10 years :  106
#  JobSkillImportanceStats JobSkillImportanceEnterpriseTools
#              :12756                  :13022
#  Necessary   : 2035      Necessary   :  535
#  Nice to have: 1812      Nice to have: 2087
#  Unnecessary :  113      Unnecessary : 1072
#
#
#
#  JobSkillImportancePython   JobSkillImportanceR  JobSkillImportanceSQL
#              :12685                   :12772                :12824
#  Necessary   : 2604       Necessary   : 1636    Necessary   : 1690
#  Nice to have: 1319       Nice to have: 2027    Nice to have: 1914
#  Unnecessary :  108       Unnecessary :  281    Unnecessary :  288
#
#
#
#  JobSkillImportanceKaggleRanking  JobSkillImportanceMOOC
#              :12846                          :12884
#  Necessary   :  460              Necessary   :  411
#  Nice to have: 2621              Nice to have: 2326
#  Unnecessary :  789              Unnecessary : 1095
#
#
#
#  JobSkillImportanceVisualizations JobSkillImportanceOtherSelect1
#              :12849                           :16358
#  Necessary   : 1761               Necessary   :  192
#  Nice to have: 1898               Nice to have:  109
#  Unnecessary :  208               Unnecessary :   57
#
#
#
#  JobSkillImportanceOtherSelect2 JobSkillImportanceOtherSelect3
#              :16544                         :16603
#  Necessary   :   75             Necessary   :   28
#  Nice to have:   60             Nice to have:   48
#  Unnecessary :   37             Unnecessary :   37
#
#
#
#            CoursePlatformSelect
#                      :14420
#  Coursera            :  636
#  Coursera,Udacity    :  252
#  Coursera,edX        :  155
#  Coursera,edX,Udacity:  131
#  Other               :  125
#  (Other)             :  997
#                                       HardwarePersonalProjectsSelect
#                                                      :12510
#  Basic laptop (Macbook)                              : 1713
#  Gaming Laptop (Laptop + CUDA capable GPU)           :  427
#  Laptop + Cloud service (AWS, Azure, GCE ...)        :  313
#  Traditional Workstation                             :  304
#  Laptop or Workstation and local IT supported servers:  268
#  (Other)                                             : 1181
#      TimeSpentStudying
#               :12688
#  0 - 1 hour   :  739
#  11 - 39 hours:  793
#  2 - 10 hours : 2323
#  40+          :  173
#
#
#                                       ProveKnowledgeSelect
#                                                 :12555
#  Experience from work in a company related to ML: 1300
#  Kaggle Competitions                            :  857
#  Online Courses and Certifications              :  592
#  Github Portfolio                               :  568
#  Master's degree                                :  454
#  (Other)                                        :  390
#           DataScienceIdentitySelect
#                        :4045
#  No                    :5314
#  Sort of (Explain more):3100
#  Yes                   :4257
#
#
#
#                                                           FormalEducation
#  Master's degree                                                  :6273
#  Bachelor's degree                                                :4811
#  Doctoral degree                                                  :2347
#                                                                   :1701
#  Some college/university study without earning a bachelor's degree: 786
#  Professional degree                                              : 451
#  (Other)                                                          : 347
#                              MajorSelect
#  Computer Science                  :4397
#                                    :3435
#  Mathematics or statistics         :2220
#  Engineering (non-computer focused):1339
#  Electrical Engineering            :1303
#  Other                             : 848
#  (Other)                           :3174
#                                 Tenure
#                                    :3184
#  1 to 2 years                      :3424
#  3 to 5 years                      :3355
#  6 to 10 years                     :1714
#  I don't write code to analyze data: 631
#  Less than a year                  :2380
#  More than 10 years                :2028
#                            PastJobTitlesSelect
#                                      :2524
#  I haven't started working yet       :1454
#  Other                               :1043
#  Researcher                          : 786
#  Software Developer/Software Engineer: 784
#  Engineer                            : 497
#  (Other)                             :9628
#                                   FirstTrainingSelect
#                                             :2004
#  Kaggle competitions                        : 257
#  Online courses (coursera, udemy, edx, etc.):5299
#  Other                                      : 307
#  Self-taught                                :3697
#  University courses                         :4162
#  Work                                       : 990
#  LearningCategorySelftTaught LearningCategoryOnlineCourses LearningCategoryWork
#  Min.   :  0.00              Min.   :  0.00                Min.   :  0.00
#  1st Qu.: 15.00              1st Qu.:  5.00                1st Qu.:  0.00
#  Median : 30.00              Median : 20.00                Median : 10.00
#  Mean   : 33.37              Mean   : 27.38                Mean   : 15.22
#  3rd Qu.: 50.00              3rd Qu.: 40.00                3rd Qu.: 25.00
#  Max.   :100.00              Max.   :100.00                Max.   :100.00
#  NA's   :3607                NA's   :3590                  NA's   :3605
#  LearningCategoryUniversity LearningCategoryKaggle LearningCategoryOther
#  Min.   :  0.00             Min.   :  0.000        Min.   :  0.000
#  1st Qu.:  0.00             1st Qu.:  0.000        1st Qu.:  0.000
#  Median :  5.00             Median :  0.000        Median :  0.000
#  Mean   : 16.99             Mean   :  5.531        Mean   :  1.796
#  3rd Qu.: 30.00             3rd Qu.: 10.000        3rd Qu.:  0.000
#  Max.   :100.00             Max.   :100.000        Max.   :100.000
#  NA's   :3594               NA's   :3590           NA's   :3622
#                                                           MLSkillsSelect
#                                                                  :3963
#  Supervised Machine Learning (Tabular Data)                      :1608
#  Supervised Machine Learning (Tabular Data),Unsupervised Learning: 550
#  Time Series                                                     : 532
#  Other (please specify; separate by semi-colon)                  : 450
#  Supervised Machine Learning (Tabular Data),Time Series          : 446
#  (Other)                                                         :9167
#                                            MLTechniquesSelect
#                                                     : 4132
#  Logistic Regression                                :  886
#  Decision Trees - Random Forests,Logistic Regression:  417
#  Other (please specify; separate by semi-colon)     :  404
#  Neural Networks - CNNs                             :  291
#  Decision Trees - Random Forests                    :  261
#  (Other)                                            :10325
#                                             ParentsEducation
#                                                     :4048
#  A bachelor's degree                                :3605
#  A master's degree                                  :2903
#  High school                                        :1973
#  Some college/university study, no bachelor's degree:1216
#  A doctoral degree                                  :1119
#  (Other)                                            :1852
#       EmployerIndustry                   EmployerSize
#               :5970                            :8945
#  Technology   :2253    10,000 or more employees:1742
#  Academic     :1643    100 to 499 employees    :1352
#  Financial    :1145    20 to 99 employees      :1192
#  Other        : 984    1,000 to 4,999 employees:1115
#  Mix of fields: 954    500 to 999 employees    : 613
#  (Other)      :3767    (Other)                 :1757
#                EmployerSizeChange            EmployerMLTime
#                         :9159                       :9065
#  Decreased significantly: 204     1-2 years         :1722
#  Decreased slightly     : 472     3-5 years         :1945
#  Increased significantly:1705     6-10 years        : 783
#  Increased slightly     :2846     Don't know        : 930
#  Stayed the same        :2330     Less than one year:1107
#                                   More than 10 years:1164
#                                                                    EmployerSearchMethod
#                                                                              :8988
#  A friend, family member, or former colleague told me                        :1924
#  I was contacted directly by someone at the company (e.g. internal recruiter):1545
#  A general-purpose job board                                                 : 919
#  Some other way                                                              : 846
#  An external recruiter or headhunter                                         : 749
#  (Other)                                                                     :1745
#                                   UniversityImportance
#                                             :8618
#  Important                                  :2347
#  N/A, I did not receive any formal education:  42
#  Not at all important                       : 317
#  Not very important                         : 772
#  Somewhat important                         :1695
#  Very important                             :2925
#                                                                                                           JobFunctionSelect
#                                                                                                                    :8735
#  Analyze and understand data to influence product or business decisions                                            :3076
#  Build and/or run a machine learning service that operationally improves your product or workflows                 :1351
#  Build and/or run the data infrastructure that your business uses for storing, analyzing, and operationalizing data: 886
#  Build prototypes to explore applying machine learning to new areas                                                :1376
#  Other                                                                                                             : 642
#  Research that advances the state of the art of machine learning                                                   : 650
#                                             WorkHardwareSelect
#                                                      :8698
#  Laptop or Workstation and private datacenters       :1138
#  Basic laptop (Macbook)                              :1050
#  Laptop + Cloud service (AWS, Azure, GCE ...)        : 954
#  Laptop or Workstation and local IT supported servers: 726
#  Traditional Workstation                             : 569
#  (Other)                                             :3581
#                  WorkDataTypeSelect     WorkProductionFrequency WorkDatasetSize
#                           :8692                     :9594              :9628
#  Relational data          :2512     Always          : 526       1GB    :1737
#  Text data,Relational data:1938     Don't know      : 206       10GB   :1428
#  Text data                :1336     Most of the time:1911       100MB  :1355
#  Other                    : 485     Never           : 733       100GB  : 803
#  Image data               : 364     Rarely          :1257       10MB   : 688
#  (Other)                  :1389     Sometimes       :2489       (Other):1077
#                                                    WorkAlgorithmsSelect
#                                                              :9415
#  Regression/Logistic Regression                              : 535
#  Other                                                       : 243
#  Decision Trees,Random Forests,Regression/Logistic Regression: 205
#  Decision Trees,Regression/Logistic Regression               : 201
#  Neural Networks                                             : 144
#  (Other)                                                     :5973
#      WorkToolsSelect    WorkToolsFrequencyAmazonML      WorkToolsFrequencyAWS
#              :8761                   :16317                        :14896
#  Python,R    : 125   Most of the time:   21        Most of the time:  516
#  R           : 123   Often           :   75        Often           :  496
#  Python      : 118   Rarely          :  161        Rarely          :  322
#  Python,R,SQL:  64   Sometimes       :  142        Sometimes       :  486
#  R,SQL       :  61
#  (Other)     :7464
#      WorkToolsFrequencyAngoss       WorkToolsFrequencyC
#                  :16694                       :15215
#  Most of the time:    5       Most of the time:  289
#  Often           :    2       Often           :  336
#  Rarely          :    9       Rarely          :  372
#  Sometimes       :    6       Sometimes       :  504
#
#
#     WorkToolsFrequencyCloudera   WorkToolsFrequencyDataRobot
#                  :16277                        :16653
#  Most of the time:  109        Most of the time:   12
#  Often           :  125        Often           :   15
#  Rarely          :   76        Rarely          :   24
#  Sometimes       :  129        Sometimes       :   12
#
#
#      WorkToolsFrequencyFlume      WorkToolsFrequencyGCP
#                  :16575                      :16192
#  Most of the time:   25      Most of the time:   96
#  Often           :   29      Often           :  136
#  Rarely          :   27      Rarely          :  112
#  Sometimes       :   60      Sometimes       :  180
#
#
#      WorkToolsFrequencyHadoop   WorkToolsFrequencyIBMCognos
#                  :15379                       :16561
#  Most of the time:  293       Most of the time:   23
#  Often           :  381       Often           :   41
#  Rarely          :  223       Rarely          :   48
#  Sometimes       :  440       Sometimes       :   43
#
#
#  WorkToolsFrequencyIBMSPSSModeler WorkToolsFrequencyIBMSPSSStatistics
#                  :16450                           :16258
#  Most of the time:   50           Most of the time:   81
#  Often           :   66           Often           :  104
#  Rarely          :   79           Rarely          :  130
#  Sometimes       :   71           Sometimes       :  143
#
#
#    WorkToolsFrequencyIBMWatson     WorkToolsFrequencyImpala
#                  :16473                        :16464
#  Most of the time:   24        Most of the time:   46
#  Often           :   49        Often           :   75
#  Rarely          :   81        Rarely          :   46
#  Sometimes       :   89        Sometimes       :   85
#
#
#       WorkToolsFrequencyJava     WorkToolsFrequencyJulia
#                  :15311                      :16536
#  Most of the time:  321      Most of the time:   17
#  Often           :  382      Often           :   21
#  Rarely          :  254      Rarely          :   87
#  Sometimes       :  448      Sometimes       :   55
#
#
#     WorkToolsFrequencyJupyter WorkToolsFrequencyKNIMECommercial
#                  :13547                       :16680
#  Most of the time: 1327       Most of the time:    8
#  Often           :  851       Often           :   10
#  Rarely          :  246       Rarely          :    6
#  Sometimes       :  745       Sometimes       :   12
#
#
#    WorkToolsFrequencyKNIMEFree  WorkToolsFrequencyMathematica
#                  :16449                        :16424
#  Most of the time:   29        Most of the time:   35
#  Often           :   39        Often           :   48
#  Rarely          :   86        Rarely          :  109
#  Sometimes       :  113        Sometimes       :  100
#
#
#      WorkToolsFrequencyMATLAB     WorkToolsFrequencyAzure
#                  :15292                       :16141
#  Most of the time:  282       Most of the time:   56
#  Often           :  313       Often           :  108
#  Rarely          :  391       Rarely          :  158
#  Sometimes       :  438       Sometimes       :  253
#
#
#      WorkToolsFrequencyExcel WorkToolsFrequencyMicrosoftRServer
#                  :15668                      :16344
#  Most of the time:  304      Most of the time:   57
#  Often           :  360      Often           :   95
#  Rarely          :   85      Rarely          :   75
#  Sometimes       :  299      Sometimes       :  145
#
#
#   WorkToolsFrequencyMicrosoftSQL    WorkToolsFrequencyMinitab
#                  :16277                          :16572
#  Most of the time:  106          Most of the time:    7
#  Often           :  123          Often           :   22
#  Rarely          :   69          Rarely          :   65
#  Sometimes       :  141          Sometimes       :   50
#
#
#      WorkToolsFrequencyNoSQL     WorkToolsFrequencyOracle
#                  :15238                      :16508
#  Most of the time:  292      Most of the time:   34
#  Often           :  431      Often           :   52
#  Rarely          :  185      Rarely          :   50
#  Sometimes       :  570      Sometimes       :   72
#
#
#      WorkToolsFrequencyOrange      WorkToolsFrequencyPerl
#                  :16594                       :16414
#  Most of the time:   10       Most of the time:   38
#  Often           :   20       Often           :   61
#  Rarely          :   45       Rarely          :   96
#  Sometimes       :   47       Sometimes       :  107
#
#
#      WorkToolsFrequencyPython      WorkToolsFrequencyQlik
#                  :10726                       :16352
#  Most of the time: 3330       Most of the time:   62
#  Often           : 1294       Often           :   69
#  Rarely          :  346       Rarely          :   94
#  Sometimes       : 1020       Sometimes       :  139
#
#
#        WorkToolsFrequencyR WorkToolsFrequencyRapidMinerCommercial
#                  :12078                    :16642
#  Most of the time: 1969    Most of the time:   16
#  Often           : 1068    Often           :   13
#  Rarely          :  467    Rarely          :   17
#  Sometimes       : 1134    Sometimes       :   28
#
#
#  WorkToolsFrequencyRapidMinerFree    WorkToolsFrequencySalfrod
#                  :16389                           :16684
#  Most of the time:   26           Most of the time:    1
#  Often           :   38           Often           :    9
#  Rarely          :  133           Rarely          :   10
#  Sometimes       :  130           Sometimes       :   12
#
#
#  WorkToolsFrequencySAPBusinessObjects    WorkToolsFrequencySASBase
#                  :16625                               :16001
#  Most of the time:   17               Most of the time:  252
#  Often           :   23               Often           :  174
#  Rarely          :   22               Rarely          :  123
#  Sometimes       :   29               Sometimes       :  166
#
#
#  WorkToolsFrequencySASEnterprise     WorkToolsFrequencySASJMP
#                  :16329                          :16601
#  Most of the time:   98          Most of the time:   26
#  Often           :   81          Often           :   30
#  Rarely          :   88          Rarely          :   27
#  Sometimes       :  120          Sometimes       :   32
#
#
#      WorkToolsFrequencySpark      WorkToolsFrequencySQL
#                  :15391                      :12528
#  Most of the time:  326      Most of the time: 2088
#  Often           :  349      Often           : 1168
#  Rarely          :  178      Rarely          :  185
#  Sometimes       :  472      Sometimes       :  747
#
#
#       WorkToolsFrequencyStan   WorkToolsFrequencyStatistica
#                  :16564                      :16674
#  Most of the time:    8      Most of the time:    4
#  Often           :   23      Often           :    8
#  Rarely          :   49      Rarely          :   13
#  Sometimes       :   72      Sometimes       :   17
#
#
#     WorkToolsFrequencyTableau   WorkToolsFrequencyTensorFlow
#                  :15132                       :14494
#  Most of the time:  360       Most of the time:  450
#  Often           :  395       Often           :  622
#  Rarely          :  309       Rarely          :  320
#  Sometimes       :  520       Sometimes       :  830
#
#
#      WorkToolsFrequencyTIBCO      WorkToolsFrequencyUnix
#                  :16577                      :14888
#  Most of the time:   29      Most of the time:  798
#  Often           :   33      Often           :  617
#  Rarely          :   31      Rarely          :   76
#  Sometimes       :   46      Sometimes       :  337
#
#
#     WorkToolsFrequencySelect1    WorkToolsFrequencySelect2
#                  :16030                       :16581
#  Most of the time:  330       Most of the time:   54
#  Often           :  183       Often           :   33
#  Rarely          :   53       Rarely          :   15
#  Sometimes       :  120       Sometimes       :   33
#
#
#        WorkFrequencySelect3            WorkMethodsSelect
#                  :16635                         :8943
#  Most of the time:   41     Data Visualization  : 144
#  Often           :   21     Other               : 144
#  Rarely          :    9     Logistic Regression :  66
#  Sometimes       :   10     Time Series Analysis:  49
#                             Neural Networks     :  45
#                             (Other)             :7325
#      WorkMethodsFrequencyA.B WorkMethodsFrequencyAssociationRules
#                  :14846                      :15620
#  Most of the time:  277      Most of the time:   89
#  Often           :  656      Often           :  328
#  Rarely          :  232      Rarely          :  156
#  Sometimes       :  705      Sometimes       :  523
#
#
#    WorkMethodsFrequencyBayesian     WorkMethodsFrequencyCNNs
#                  :14871                         :15363
#  Most of the time:  236         Most of the time:  383
#  Often           :  622         Often           :  473
#  Rarely          :  193         Rarely          :   91
#  Sometimes       :  794         Sometimes       :  406
#
#
#  WorkMethodsFrequencyCollaborativeFiltering
#                  :15955
#  Most of the time:   91
#  Often           :  257
#  Rarely          :   92
#  Sometimes       :  321
#
#
#  WorkMethodsFrequencyCross.Validation WorkMethodsFrequencyDataVisualization
#                  :12956                               :11810
#  Most of the time: 1632               Most of the time: 2927
#  Often           : 1331               Often           : 1487
#  Rarely          :   96               Rarely          :   47
#  Sometimes       :  701               Sometimes       :  445
#
#
#  WorkMethodsFrequencyDecisionTrees WorkMethodsFrequencyEnsembleMethods
#                  :13134                            :14733
#  Most of the time:  764            Most of the time:  504
#  Often           : 1409            Often           :  764
#  Rarely          :  218            Rarely          :   89
#  Sometimes       : 1191            Sometimes       :  626
#
#
#  WorkMethodsFrequencyEvolutionaryApproaches     WorkMethodsFrequencyGANs
#                  :16302                                     :16486
#  Most of the time:   69                     Most of the time:   28
#  Often           :  127                     Often           :   68
#  Rarely          :   43                     Rarely          :   34
#  Sometimes       :  175                     Sometimes       :  100
#
#
#      WorkMethodsFrequencyGBM     WorkMethodsFrequencyHMMs
#                  :15211                      :16317
#  Most of the time:  450      Most of the time:   48
#  Often           :  580      Often           :  108
#  Rarely          :   55      Rarely          :   68
#  Sometimes       :  420      Sometimes       :  175
#
#
#      WorkMethodsFrequencyKNN WorkMethodsFrequencyLiftAnalysis
#                  :14171                      :16093
#  Most of the time:  368      Most of the time:  117
#  Often           :  983      Often           :  238
#  Rarely          :  163      Rarely          :   61
#  Sometimes       : 1031      Sometimes       :  207
#
#
#  WorkMethodsFrequencyLogisticRegression     WorkMethodsFrequencyMLN
#                  :12544                                 :16474
#  Most of the time: 1027                 Most of the time:   31
#  Often           : 1731                 Often           :   74
#  Rarely          :  201                 Rarely          :   29
#  Sometimes       : 1213                 Sometimes       :  108
#
#
#   WorkMethodsFrequencyNaiveBayes     WorkMethodsFrequencyNLP
#                  :14910                          :14840
#  Most of the time:  248          Most of the time:  564
#  Often           :  577          Often           :  686
#  Rarely          :  185          Rarely          :  107
#  Sometimes       :  796          Sometimes       :  519
#
#
#  WorkMethodsFrequencyNeuralNetworks     WorkMethodsFrequencyPCA
#                  :14006                             :14014
#  Most of the time:  781             Most of the time:  545
#  Often           :  950             Often           : 1075
#  Rarely          :  159             Rarely          :  142
#  Sometimes       :  820             Sometimes       :  940
#
#
#  WorkMethodsFrequencyPrescriptiveModeling WorkMethodsFrequencyRandomForests
#                  :15899                                   :13360
#  Most of the time:  185                   Most of the time:  762
#  Often           :  348                   Often           : 1319
#  Rarely          :   42                   Rarely          :  189
#  Sometimes       :  242                   Sometimes       : 1086
#
#
#  WorkMethodsFrequencyRecommenderSystems     WorkMethodsFrequencyRNNs
#                  :15604                                 :15868
#  Most of the time:  201                 Most of the time:  197
#  Often           :  395                 Often           :  333
#  Rarely          :  100                 Rarely          :   46
#  Sometimes       :  416                 Sometimes       :  272
#
#
#  WorkMethodsFrequencySegmentation  WorkMethodsFrequencySimulation
#                  :14739                           :15365
#  Most of the time:  468           Most of the time:  370
#  Often           :  799           Often           :  511
#  Rarely          :   97           Rarely          :   88
#  Sometimes       :  613           Sometimes       :  382
#
#
#      WorkMethodsFrequencySVMs WorkMethodsFrequencyTextAnalysis
#                  :14813                       :14385
#  Most of the time:  344       Most of the time:  618
#  Often           :  667       Often           :  865
#  Rarely          :  157       Rarely          :  140
#  Sometimes       :  735       Sometimes       :  708
#
#
#  WorkMethodsFrequencyTimeSeriesAnalysis   WorkMethodsFrequencySelect1
#                  :13644                                 :16483
#  Most of the time:  870                 Most of the time:  113
#  Often           : 1149                 Often           :   53
#  Rarely          :  158                 Rarely          :   33
#  Sometimes       :  895                 Sometimes       :   34
#
#
#    WorkMethodsFrequencySelect2   WorkMethodsFrequencySelect3 TimeGatheringData
#                  :16677                        :16623        Min.   :  0.00
#  Most of the time:   14        Most of the time:   33        1st Qu.: 20.00
#  Often           :   12        Often           :   24        Median : 35.00
#  Rarely          :    6        Rarely          :   25        Mean   : 36.15
#  Sometimes       :    7        Sometimes       :   11        3rd Qu.: 50.00
#                                                              Max.   :100.00
#                                                              NA's   :9186
#  TimeModelBuilding TimeProduction   TimeVisualizing  TimeFindingInsights
#  Min.   :  0.00    Min.   :  0.00   Min.   :  0.00   Min.   :  0.0
#  1st Qu.: 10.00    1st Qu.:  0.00   1st Qu.:  5.00   1st Qu.:  5.0
#  Median : 20.00    Median : 10.00   Median : 10.00   Median : 10.0
#  Mean   : 21.27    Mean   : 10.81   Mean   : 13.87   Mean   : 13.1
#  3rd Qu.: 30.00    3rd Qu.: 15.00   3rd Qu.: 20.00   3rd Qu.: 20.0
#  Max.   :100.00    Max.   :100.00   Max.   :100.00   Max.   :303.0
#  NA's   :9188      NA's   :9199     NA's   :9187     NA's   :9193
#  TimeOtherSelect
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  0.000
#  Mean   :  2.396
#  3rd Qu.:  0.000
#  Max.   :100.000
#  NA's   :9203
#                                                                        AlgorithmUnderstandingLevel
#                                                                                      :9306
# ...
#  I prefer not to say                                                            : 411
#  Company politics / Lack of management/financial support for a data science team: 110
#  Dirty data                                                                     : 110
#  Lack of data science talent in the organization                                : 103
#  Other                                                                          : 100
#  (Other)                                                                        :6542
#   WorkChallengeFrequencyPolitics WorkChallengeFrequencyUnusedResults
#                  :14036                          :14972
#  Most of the time:  699          Most of the time:  271
#  Often           : 1073          Often           :  765
#  Rarely          :   95          Rarely          :   57
#  Sometimes       :  813          Sometimes       :  651
#
#
#  WorkChallengeFrequencyUnusefulInstrumenting WorkChallengeFrequencyDeployment
#                  :16077                                      :15869
#  Most of the time:  102                      Most of the time:  111
#  Often           :  256                      Often           :  332
#  Rarely          :   32                      Rarely          :   31
#  Sometimes       :  249                      Sometimes       :  373
#
#
#  WorkChallengeFrequencyDirtyData WorkChallengeFrequencyExplaining
#                  :13165                          :15131
#  Most of the time: 1516          Most of the time:  301
#  Often           : 1433          Often           :  657
#  Rarely          :   26          Rarely          :   52
#  Sometimes       :  576          Sometimes       :  575
#
#
#     WorkChallengeFrequencyPass WorkChallengeFrequencyIntegration
#                  :16292                        :15744
#  Most of the time:  112        Most of the time:  186
#  Often           :   77        Often           :  422
#  Rarely          :  113        Rarely          :   32
#  Sometimes       :  122        Sometimes       :  332
#
#
#    WorkChallengeFrequencyTalent WorkChallengeFrequencyDataFunds
#                  :13720                         :15764
#  Most of the time:  915         Most of the time:  265
#  Often           : 1208         Often           :  348
#  Rarely          :   71         Rarely          :   51
#  Sometimes       :  802         Sometimes       :  288
#
#
#  WorkChallengeFrequencyDomainExpertise     WorkChallengeFrequencyML
#                  :15308                                :15951
#  Most of the time:  308                Most of the time:  143
#  Often           :  649                Often           :  321
#  Rarely          :   36                Rarely          :   51
#  Sometimes       :  415                Sometimes       :  250
#
#
#    WorkChallengeFrequencyTools WorkChallengeFrequencyExpectations
#                  :15537                        :15582
#  Most of the time:  257        Most of the time:  219
#  Often           :  478        Often           :  489
#  Rarely          :   39        Rarely          :   41
#  Sometimes       :  405        Sometimes       :  385
#
#
#  WorkChallengeFrequencyITCoordination WorkChallengeFrequencyHiringFunds
#                  :15547                               :15429
#  Most of the time:  386               Most of the time:  478
#  Often           :  448               Often           :  462
#  Rarely          :   36               Rarely          :   38
#  Sometimes       :  299               Sometimes       :  309
#
#
#   WorkChallengeFrequencyPrivacy  WorkChallengeFrequencyScaling
#                  :15294                         :15883
#  Most of the time:  360         Most of the time:  169
#  Often           :  507         Often           :  356
#  Rarely          :   74         Rarely          :   41
#  Sometimes       :  481         Sometimes       :  267
#
#
#  WorkChallengeFrequencyEnvironments  WorkChallengeFrequencyClarity
#                  :15463                             :14537
#  Most of the time:  335             Most of the time:  622
#  Often           :  496             Often           :  933
#  Rarely          :   46             Rarely          :   41
#  Sometimes       :  376             Sometimes       :  583
#
#
#  WorkChallengeFrequencyDataAccess WorkChallengeFrequencyOtherSelect
#                  :14526                           :16439
#  Most of the time:  620           Most of the time:  129
#  Often           :  923           Often           :   81
#  Rarely          :   53           Rarely          :   27
#  Sometimes       :  594           Sometimes       :   40
#
#
#         WorkDataVisualizations
#                    :9837
#  10-25% of projects:1265
#  76-99% of projects:1255
#  100% of projects  :1253
#  51-75% of projects:1160
#  26-50% of projects: 918
#  (Other)           :1028
#                                 WorkInternalVsExternalTools
#                                               :9959
#  Approximately half internal and half external: 927
#  Do not know                                  : 577
#  Entirely external                            : 198
#  Entirely internal                            :1934
#  More external than internal                  : 673
#  More internal than external                  :2448
#             WorkMLTeamSeatSelect  WorkDatasets   WorkDatasetsChallenge
#                       :10028            :14488             :14132
#  Business Department  :  937     None   :  156   dirty data:   27
#  Central Insights Team:  604     none   :   72   Dirty data:   26
#  IT Department        : 1662     N/A    :   21   Cleaning  :   20
#  Other                : 1241     Census :   14   cleaning  :   14
#  Standalone Team      : 2244     (Other): 1945   (Other)   : 2483
#                                  NA's   :   20   NA's      :   14
#                                                                                                                                                                                   WorkDataStorage
#                                                                                                                                                                                           :10201
#  Flat files not in a database or cache (e.g. CSV, JSON, XML, PNG, MPG),Row-oriented relational (e.g. MySQL/Microsoft SQL Server)                                                          : 1333
#  Flat files not in a database or cache (e.g. CSV, JSON, XML, PNG, MPG)                                                                                                                    : 1151
#  Row-oriented relational (e.g. MySQL/Microsoft SQL Server)                                                                                                                                :  718
#  Document-oriented (e.g. MongoDB/Elasticsearch),Flat files not in a database or cache (e.g. CSV, JSON, XML, PNG, MPG),Row-oriented relational (e.g. MySQL/Microsoft SQL Server)           :  312
#  Flat files not in a database or cache (e.g. CSV, JSON, XML, PNG, MPG),Other tabular (e.g. Cassandra/BigTable/BigQuery/Redshift),Row-oriented relational (e.g. MySQL/Microsoft SQL Server):  195
#  (Other)                                                                                                                                                                                  : 2806
#                      WorkDataSharing      WorkDataSourcing
#                              :10214               :16335
#  Company Developed Platform  :  993   S3          :   15
#  I don't typically share data:  968   Dropbox     :   12
#  Commercial Data Platform    :  801   Google Drive:   10
#  Share Drive/SharePoint      :  761   AWS S3      :    7
#  Email,Share Drive/SharePoint:  497   Slack       :    7
#  (Other)                     : 2482   (Other)     :  330
#                                                            WorkCodeSharing
#                                                                    :10513
#  Git                                                               : 2017
#  Generic non-cloud file sharing software (Email/Shared Server/etc.):  809
#  Bitbucket                                                         :  376
#  Bitbucket,Git                                                     :  364
#  Other                                                             :  363
#  (Other)                                                           : 2274
#             RemoteWork    CompensationAmount CompensationCurrency
#                  :10619          :11492             :12186
#  Always          :  352   100000 :  151      USD    : 1577
#  Don't know      :   26   60000  :  142      EUR    :  798
#  Most of the time:  684   50000  :  132      INR    :  496
#  Never           :  823   120000 :  118      GBP    :  174
#  Rarely          : 1772   80000  :  114      BRL    :  131
#  Sometimes       : 2440   (Other): 4567      (Other): 1354
#                                                                   SalaryChange
#                                                                         :10327
#  Has increased 20% or more                                              : 1941
#  Has increased between 6% and 19%                                       : 1469
#  Has stayed about the same (has not increased or decreased more than 5%): 1351
#  I was not employed 3 years ago                                         :  637
#  I do not want to share information about my salary/compensation        :  615
#  (Other)                                                                :  376
#  JobSatisfaction
#         :10039
#  7      : 1448
#  8      : 1427
#  6      :  765
#  9      :  677
#  5      :  627
#  (Other): 1733
#                                                       JobSearchResource
#                                                                :12977
#  Company's Web site/job listing page                           :  911
#  Tech-specific job board                                       :  732
#  Searching general-purpose job board                           :  684
#  Asking friends, family members, or former colleagues for leads:  445
#  Meeting with recruiters who've contacted you directly         :  363
#  (Other)                                                       :  604
#   JobHuntTime             JobFactorLearning           JobFactorSalary
#         :12985                     :13165                     :13231
#  0      : 1500   Not important     :   87   Not important     :  174
#  1-2    : 1288   Somewhat important:  896   Somewhat important: 1704
#  3-5    :  524   Very Important    : 2568   Very Important    : 1607
#  6-10   :  229
#  11-15  :   92
#  (Other):   98
#            JobFactorOffice           JobFactorLanguages
#                    :13248                     :13241
#  Not important     :  210   Not important     :  248
#  Somewhat important: 1408   Somewhat important: 1540
#  Very Important    : 1850   Very Important    : 1687
#
#
#
#            JobFactorCommute         JobFactorManagement
#                    :13269                     :13282
#  Not important     :  456   Not important     :  309
#  Somewhat important: 1800   Somewhat important: 1602
#  Very Important    : 1191   Very Important    : 1523
#
#
#
#        JobFactorExperienceLevel         JobFactorDepartment
#                    :13279                         :13300
#  Not important     :  317       Not important     :  564
#  Somewhat important: 1701       Somewhat important: 1649
#  Very Important    : 1419       Very Important    : 1203
#
#
#
#             JobFactorTitle        JobFactorCompanyFunding
#                    :13302                     :13305
#  Not important     :  512   Not important     :  511
#  Somewhat important: 1518   Somewhat important: 1918
#  Very Important    : 1384   Very Important    :  982
#
#
#
#            JobFactorImpact            JobFactorRemote
#                    :13322                     :13292
#  Not important     :  393   Not important     :  955
#  Somewhat important: 1666   Somewhat important: 1509
#  Very Important    : 1335   Very Important    :  960
#
#
#
#           JobFactorIndustry      JobFactorLeaderReputation
#                    :13307                     :13315
#  Not important     :  616   Not important     :  712
#  Somewhat important: 1724   Somewhat important: 1769
#  Very Important    : 1069   Very Important    :  920
#
#
#
#           JobFactorDiversity    JobFactorPublishingOpportunity
#                    :13306                      :13292
#  Not important     :  852    Not important     :  703
#  Somewhat important: 1662    Somewhat important: 1503
#  Very Important    :  896    Very Important    : 1218

# %%
schema
# Out:
#     Column
# 1   GenderSelect
# 2   GenderFreeForm
# 3   Country
# 4   Age
# 5   EmploymentStatus
# 6   StudentStatus
# 7   LearningDataScience
# 8   KaggleMotivationFreeForm
# 9   CodeWriter
# 10  CareerSwitcher
# 11  CurrentJobTitleSelect
# 12  CurrentJobTitleFreeForm
# 13  TitleFit
# 14  CurrentEmployerType
# 15  MLToolNextYearSelect
# 16  MLToolNextYearFreeForm
# 17  MLMethodNextYearSelect
# 18  MLMethodNextYearFreeForm
# 19  LanguageRecommendationSelect
# 20  LanguageRecommendationFreeForm
# 21  PublicDatasetsSelect
# 22  PublicDatasetsFreeForm
# 23  PersonalProjectsChallengeFreeForm
# 24  LearningPlatformSelect
# 25  LearningPlatformCommunityFreeForm
# 26  LearningPlatformFreeForm1
# 27  LearningPlatformFreeForm2
# 28  LearningPlatformFreeForm3
# 29  LearningPlatformUsefulnessArxiv
# 30  LearningPlatformUsefulnessBlogs
# ⋮   ⋮
# 261 WorkDataStorageFreeForm
# 262 WorkDataSharing
# 263 WorkDataSourcing
# 264 WorkCodeSharing
# 265 WorkCodeSharingFreeForm
# 266 RemoteWork
# 267 CompensationAmount
# 268 CompensationCurrency
# 269 SalaryChange
# 270 SalaryChangeFreeForm
# 271 JobSatisfaction
# 272 JobSearchResource
# 273 JobSearchResourceFreeForm
# 274 JobHuntTime
# 275 JobFactorLearning
# 276 JobFactorSalary
# 277 JobFactorOffice
# 278 JobFactorLanguages
# 279 JobFactorCommute
# 280 JobFactorManagement
# 281 JobFactorExperienceLevel
# 282 JobFactorDepartment
# 283 JobFactorTitle
# 284 JobFactorCompanyFunding
# 285 JobFactorImpact
# 286 JobFactorRemote
# 287 JobFactorIndustry
# 288 JobFactorLeaderReputation
# 289 JobFactorDiversity
# 290 JobFactorPublishingOpportunity
#     Question
# 1   Select your gender identity. - Selected Choice
# 2   Select your gender identity. - A different identity - Text
# 3   Select the country you currently live in.
# 4   What's your age?
# 5   What's your current employment status?
# 6   Are you currently enrolled as a student at a degree granting school?
# 7   Are you currently focused on learning data science skills either formally or informally?
# 8   What's your motivation for being a Kaggle user?
# 9   Do you write code to analyze data in your current job, freelance contracts, or most recent job if retired?
# 10  Are you actively looking to switch careers to data science?
# 11  Select the option that's most similar to your current job/professional title (or most recent title if retired). - Selected Choice
# 12  Select the option that's most similar to your current job/professional title (or most recent title if retired). - Other - Text
# 13  How adequately do you feel your title describes what you do (or what you did if retired)?
# 14  Which of the following describe your current employer (or most recent employer if retired)? (Select all that apply)
# 15  Which tool or technology are you most excited about learning in the next year? (Select one option) - Selected Choice
# 16  Which tool or technology are you most excited about learning in the next year? (Select one option) - Other - Text
# 17  Which ML/DS method are you most excited about learning in the next year? (Select one option) - Selected Choice
# 18  Which ML/DS method are you most excited about learning in the next year? (Select one option) - Other - Text
# 19  What programming language would you recommend a new data scientist learn first? (Select one option) - Selected Choice
# 20  What programming language would you recommend a new data scientist learn first? (Select one option) - Other - Text
# 21  Where do you find public datasets to practice data science skills? (Select all that apply) - Selected Choice
# 22  Where do you find public datasets to practice data science skills? (Select all that apply) - Other - Text
# 23  What is your biggest challenge with the public datasets you find for personal projects?
# 24  What platforms & resources have you used to continue learning data science skills? (Select all that apply) - Selected Choice
# 25  What platforms & resources have you used to continue learning data science skills? (Select all that apply) - Non-Kaggle online communities - Text
# 26  What platforms & resources have you used to continue learning data science skills? (Select all that apply) - Other - Text1
# 27  What platforms & resources have you used to continue learning data science skills? (Select all that apply) - Other - Text2
# 28  What platforms & resources have you used to continue learning data science skills? (Select all that apply) - Other - Text3
# 29  How useful did you find these platforms & resources for learning data science skills? - Arxiv
# 30  How useful did you find these platforms & resources for learning data science skills? - Blogs
# ⋮   ⋮
# 261 At work, which of these data storage models do you typically use? (Select all that apply) - Other - Text
# 262 At work, which tools do you use to share source data? (Select all that apply) - Selected Choice
# 263 At work, which tools do you use to share source data? (Select all that apply) - Other - Text
# 264 At work, which tools do you use to share code? (Select all that apply) - Selected Choice
# 265 At work, which tools do you use to share code? (Select all that apply) - Other - Text
# 266 How often do you work remotely?
# 267 What is your current total yearly compensation (salary + bonus)? - Total Amount (e.g. 75,000) - Your Compensation: -
# 268 What is your current total yearly compensation (salary + bonus)? - Choose your currency: - Your Compensation:
# 269 How has your salary/compensation changed in the past 3 years? - Selected Choice
# 270 How has your salary/compensation changed in the past 3 years? - Other - Text
# 271 On a scale from 0 (Highly Dissatisfied) - 10 (Highly Satisfied), how satisfied are you with your current job?
# 272 Which resource has been the best for finding data science job openings? (Select one option) - Selected Choice
# 273 Which resource has been the best for finding data science job openings? (Select one option) - Other - Text
# 274 How many hours per week have you typically spend looking for a data science job?
# 275 How are you assessing potential job opportunities? - Opportunities for professional development
# 276 How are you assessing potential job opportunities? - The compensation and benefits offered
# 277 How are you assessing potential job opportunities? - The office environment I'd be working in
# 278 How are you assessing potential job opportunities? - The languages, frameworks, and other technologies I'd be working with
# 279 How are you assessing potential job opportunities? - The amount of time I'd have to spend commuting
# 280 How are you assessing potential job opportunities? - How projects are managed at the company or organization
# 281 How are you assessing potential job opportunities? - The experience level called for in the job description
# 282 How are you assessing potential job opportunities? - The specific department or team I'd be working on
# 283 How are you assessing potential job opportunities? - The specific role or job title I'd be applying for
# 284 How are you assessing potential job opportunities? - The financial performance or funding status of the company or organization
# 285 How are you assessing potential job opportunities? - How widely used or impactful the product or service I'd be working on is
# 286 How are you assessing potential job opportunities? - The opportunity to work from home/remotely
# 287 How are you assessing potential job opportunities? - The industry that I'd be working in
# 288 How are you assessing potential job opportunities? - The reputations of the company's senior leaders
# 289 How are you assessing potential job opportunities? - The diversity of the company or organization
# 290 How are you assessing potential job opportunities? - Opportunity to publish my results
#     Asked
# 1   All
# 2   All
# 3   All
# 4   All
# 5   All
# 6   Non-worker
# 7   Non-worker
# 8   Non-switcher
# 9   Worker1
# 10  Worker1
# 11  Worker1
# 12  Worker1
# 13  Worker1
# 14  Worker1
# 15  All
# 16  All
# 17  All
# 18  All
# 19  All
# 20  All
# 21  All
# 22  All
# 23  All
# 24  All
# 25  All
# 26  All
# 27  All
# 28  All
# 29  All
# 30  All
# ⋮   ⋮
# 261 CodingWorker
# 262 CodingWorker
# 263 CodingWorker
# 264 CodingWorker
# 265 CodingWorker
# 266 CodingWorker
# 267 CodingWorker
# 268 CodingWorker
# 269 CodingWorker
# 270 CodingWorker
# 271 CodingWorker
# 272 Learners
# 273 Learners
# 274 Learners
# 275 Learners
# 276 Learners
# 277 Learners
# 278 Learners
# 279 Learners
# 280 Learners
# 281 Learners
# 282 Learners
# 283 Learners
# 284 Learners
# 285 Learners
# 286 Learners
# 287 Learners
# 288 Learners
# 289 Learners
# 290 Learners

# %% [markdown]
# 1. Who are the respondents? Country, age, gender, education (degree, major,)

# %%
# specify map projection/options
l <- list(color = toRGB("grey"), width = 0.5)


g <- list(
showframe = FALSE,
showcoastlines = FALSE,
projection = list(type = 'Mercator')
)

# %%
df <- (multiRes %>%
    group_by(Country) %>%
    count()) 
p <- (plot_geo(df) %>%
     add_trace(z = ~n, color = ~n, colors = 'Blues', text = ~Country, locations = ~Country, marker = list(line = l)) %>%
    layout(title = '2014 Global GDP', geo = g))
p
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# 2. Employment and Salary(with conversion, distribution by country, gender).

# %% [markdown]
# 3. Python vs. R (gloabal distribution, by industry, job title, by data type, by ML skills algorithms)

# %% [markdown]
# 4. Learners, Learning experience and resources, time spent

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# ---

# %% [markdown]
# ## 6. References
